# %%
# !pip install plot_keras_history
# !pip install statsmodels==0.10.1
# Out:
# Requirement already satisfied: plot_keras_history in d:\anaconda\lib\site-packages (1.1.38)
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (from plot_keras_history) (3.7.2)
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (from plot_keras_history) (2.0.3)
# Requirement already satisfied: scipy in d:\anaconda\lib\site-packages (from plot_keras_history) (1.11.1)
# Requirement already satisfied: support-developer>=1.0.2 in d:\anaconda\lib\site-packages (from plot_keras_history) (1.0.5)
# Requirement already satisfied: sanitize-ml-labels>=1.0.48 in d:\anaconda\lib\site-packages (from plot_keras_history) (1.0.51)
# Requirement already satisfied: compress-json in d:\anaconda\lib\site-packages (from sanitize-ml-labels>=1.0.48->plot_keras_history) (1.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->plot_keras_history) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib->plot_keras_history) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib->plot_keras_history) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->plot_keras_history) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in d:\anaconda\lib\site-packages (from matplotlib->plot_keras_history) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib->plot_keras_history) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib->plot_keras_history) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib->plot_keras_history) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib->plot_keras_history) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas->plot_keras_history) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda\lib\site-packages (from pandas->plot_keras_history) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->plot_keras_history) (1.16.0)
# Collecting statsmodels==0.10.1
#   Using cached statsmodels-0.10.1.tar.gz (14.1 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.11 in d:\anaconda\lib\site-packages (from statsmodels==0.10.1) (1.24.3)
# Requirement already satisfied: scipy>=0.18 in d:\anaconda\lib\site-packages (from statsmodels==0.10.1) (1.11.1)
# Requirement already satisfied: pandas>=0.19 in d:\anaconda\lib\site-packages (from statsmodels==0.10.1) (2.0.3)
# Requirement already satisfied: patsy>=0.4.0 in d:\anaconda\lib\site-packages (from statsmodels==0.10.1) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas>=0.19->statsmodels==0.10.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas>=0.19->statsmodels==0.10.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda\lib\site-packages (from pandas>=0.19->statsmodels==0.10.1) (2023.3)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from patsy>=0.4.0->statsmodels==0.10.1) (1.16.0)
# Building wheels for collected packages: statsmodels
#   Building wheel for statsmodels (setup.py): started
#   Building wheel for statsmodels (setup.py): finished with status 'error'
#   Running setup.py clean for statsmodels
# Failed to build statsmodels
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [1334 lines of output]
#   C:\Users\61723\AppData\Local\Temp\pip-install-2eiu8097\statsmodels_ed9dbf2378954d7e92d2d01ffc125b59\setup.py:14: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#     import pkg_resources
#   C:\Users\61723\AppData\Local\Temp\pip-install-2eiu8097\statsmodels_ed9dbf2378954d7e92d2d01ffc125b59\setup.py:50: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     req_ver = LooseVersion(SETUP_REQUIREMENTS[key])
#   C:\Users\61723\AppData\Local\Temp\pip-install-2eiu8097\statsmodels_ed9dbf2378954d7e92d2d01ffc125b59\setup.py:53: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     ver = LooseVersion(mod.__version__)
#   C:\Users\61723\AppData\Local\Temp\pip-install-2eiu8097\statsmodels_ed9dbf2378954d7e92d2d01ffc125b59\setup.py:50: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     req_ver = LooseVersion(SETUP_REQUIREMENTS[key])
#   D:\anaconda\Lib\site-packages\setuptools\config\setupcfg.py:293: _DeprecatedConfig: Deprecated config in `setup.cfg`
#   !!
#
#           ********************************************************************************
#           The license_file parameter is deprecated, use license_files instead.
#
#           This deprecation is overdue, please update your project and remove deprecated
#           calls to avoid build errors in the future.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     parsed = self.parsers.get(option_name, lambda x: x)(value)
#   D:\anaconda\Lib\site-packages\setuptools\__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#   !!
#
#           ********************************************************************************
#           Requirements should be satisfied by a PEP 517 installer.
#           If you are using pip, you can try `pip install --use-pep517`.
#           ********************************************************************************
#
#   !!
#     dist.fetch_build_eggs(dist.setup_requires)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-311
#   creating build\lib.win-amd64-cpython-311\statsmodels
#   copying statsmodels\api.py -> build\lib.win-amd64-cpython-311\statsmodels
#   copying statsmodels\conftest.py -> build\lib.win-amd64-cpython-311\statsmodels
#   copying statsmodels\_version.py -> build\lib.win-amd64-cpython-311\statsmodels
#   copying statsmodels\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels
#   creating build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\covtype.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\data.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\distributed_estimation.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\elastic_net.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\l1_cvxopt.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\l1_slsqp.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\l1_solvers_common.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\model.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\optimizer.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\transform.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\wrapper.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\_constraints.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\_parameter_inference.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\_penalized.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\_penalties.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\_screening.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   copying statsmodels\base\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\base
#   creating build\lib.win-amd64-cpython-311\statsmodels\compat
#   copying statsmodels\compat\numpy.py -> build\lib.win-amd64-cpython-311\statsmodels\compat
#   copying statsmodels\compat\pandas.py -> build\lib.win-amd64-cpython-311\statsmodels\compat
#   copying statsmodels\compat\platform.py -> build\lib.win-amd64-cpython-311\statsmodels\compat
#   copying statsmodels\compat\python.py -> build\lib.win-amd64-cpython-311\statsmodels\compat
#   copying statsmodels\compat\scipy.py -> build\lib.win-amd64-cpython-311\statsmodels\compat
#   copying statsmodels\compat\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\compat
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets
#   copying statsmodels\datasets\template_data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets
#   copying statsmodels\datasets\utils.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets
#   copying statsmodels\datasets\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets
#   creating build\lib.win-amd64-cpython-311\statsmodels\discrete
#   copying statsmodels\discrete\conditional_models.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete
#   copying statsmodels\discrete\count_model.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete
#   copying statsmodels\discrete\discrete_margins.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete
#   copying statsmodels\discrete\discrete_model.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete
#   copying statsmodels\discrete\_diagnostics_count.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete
#   copying statsmodels\discrete\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete
#   creating build\lib.win-amd64-cpython-311\statsmodels\distributions
#   copying statsmodels\distributions\discrete.py -> build\lib.win-amd64-cpython-311\statsmodels\distributions
#   copying statsmodels\distributions\edgeworth.py -> build\lib.win-amd64-cpython-311\statsmodels\distributions
#   copying statsmodels\distributions\empirical_distribution.py -> build\lib.win-amd64-cpython-311\statsmodels\distributions
#   copying statsmodels\distributions\mixture_rvs.py -> build\lib.win-amd64-cpython-311\statsmodels\distributions
#   copying statsmodels\distributions\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\distributions
#   creating build\lib.win-amd64-cpython-311\statsmodels\duration
#   copying statsmodels\duration\api.py -> build\lib.win-amd64-cpython-311\statsmodels\duration
#   copying statsmodels\duration\hazard_regression.py -> build\lib.win-amd64-cpython-311\statsmodels\duration
#   copying statsmodels\duration\survfunc.py -> build\lib.win-amd64-cpython-311\statsmodels\duration
#   copying statsmodels\duration\_kernel_estimates.py -> build\lib.win-amd64-cpython-311\statsmodels\duration
#   copying statsmodels\duration\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\duration
#   creating build\lib.win-amd64-cpython-311\statsmodels\emplike
#   copying statsmodels\emplike\aft_el.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike
#   copying statsmodels\emplike\api.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike
#   copying statsmodels\emplike\descriptive.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike
#   copying statsmodels\emplike\elanova.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike
#   copying statsmodels\emplike\elregress.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike
#   copying statsmodels\emplike\originregress.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike
#   copying statsmodels\emplike\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike
#   creating build\lib.win-amd64-cpython-311\statsmodels\formula
#   copying statsmodels\formula\api.py -> build\lib.win-amd64-cpython-311\statsmodels\formula
#   copying statsmodels\formula\formulatools.py -> build\lib.win-amd64-cpython-311\statsmodels\formula
#   copying statsmodels\formula\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\formula
#   creating build\lib.win-amd64-cpython-311\statsmodels\gam
#   copying statsmodels\gam\api.py -> build\lib.win-amd64-cpython-311\statsmodels\gam
#   copying statsmodels\gam\gam_penalties.py -> build\lib.win-amd64-cpython-311\statsmodels\gam
#   copying statsmodels\gam\generalized_additive_model.py -> build\lib.win-amd64-cpython-311\statsmodels\gam
#   copying statsmodels\gam\smooth_basis.py -> build\lib.win-amd64-cpython-311\statsmodels\gam
#   copying statsmodels\gam\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\gam
#   creating build\lib.win-amd64-cpython-311\statsmodels\genmod
#   copying statsmodels\genmod\api.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod
#   copying statsmodels\genmod\bayes_mixed_glm.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod
#   copying statsmodels\genmod\cov_struct.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod
#   copying statsmodels\genmod\generalized_estimating_equations.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod
#   copying statsmodels\genmod\generalized_linear_model.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod
#   copying statsmodels\genmod\qif.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod
#   copying statsmodels\genmod\_prediction.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod
#   copying statsmodels\genmod\_tweedie_compound_poisson.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod
#   copying statsmodels\genmod\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod
#   creating build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\agreement.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\api.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\boxplots.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\correlation.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\dotplots.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\factorplots.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\functional.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\gofplots.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\mosaicplot.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\plottools.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\plot_grids.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\regressionplots.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\tsaplots.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\tukeyplot.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\utils.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\_regressionplots_doc.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   copying statsmodels\graphics\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\graphics
#   creating build\lib.win-amd64-cpython-311\statsmodels\imputation
#   copying statsmodels\imputation\bayes_mi.py -> build\lib.win-amd64-cpython-311\statsmodels\imputation
#   copying statsmodels\imputation\mice.py -> build\lib.win-amd64-cpython-311\statsmodels\imputation
#   copying statsmodels\imputation\ros.py -> build\lib.win-amd64-cpython-311\statsmodels\imputation
#   copying statsmodels\imputation\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\imputation
#   creating build\lib.win-amd64-cpython-311\statsmodels\interface
#   copying statsmodels\interface\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\interface
#   creating build\lib.win-amd64-cpython-311\statsmodels\iolib
#   copying statsmodels\iolib\api.py -> build\lib.win-amd64-cpython-311\statsmodels\iolib
#   copying statsmodels\iolib\foreign.py -> build\lib.win-amd64-cpython-311\statsmodels\iolib
#   copying statsmodels\iolib\openfile.py -> build\lib.win-amd64-cpython-311\statsmodels\iolib
#   copying statsmodels\iolib\smpickle.py -> build\lib.win-amd64-cpython-311\statsmodels\iolib
#   copying statsmodels\iolib\stata_summary_examples.py -> build\lib.win-amd64-cpython-311\statsmodels\iolib
#   copying statsmodels\iolib\summary.py -> build\lib.win-amd64-cpython-311\statsmodels\iolib
#   copying statsmodels\iolib\summary2.py -> build\lib.win-amd64-cpython-311\statsmodels\iolib
#   copying statsmodels\iolib\table.py -> build\lib.win-amd64-cpython-311\statsmodels\iolib
#   copying statsmodels\iolib\tableformatting.py -> build\lib.win-amd64-cpython-311\statsmodels\iolib
#   copying statsmodels\iolib\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\iolib
#   creating build\lib.win-amd64-cpython-311\statsmodels\miscmodels
#   copying statsmodels\miscmodels\api.py -> build\lib.win-amd64-cpython-311\statsmodels\miscmodels
#   copying statsmodels\miscmodels\count.py -> build\lib.win-amd64-cpython-311\statsmodels\miscmodels
#   copying statsmodels\miscmodels\nonlinls.py -> build\lib.win-amd64-cpython-311\statsmodels\miscmodels
#   copying statsmodels\miscmodels\tmodel.py -> build\lib.win-amd64-cpython-311\statsmodels\miscmodels
#   copying statsmodels\miscmodels\try_mlecov.py -> build\lib.win-amd64-cpython-311\statsmodels\miscmodels
#   copying statsmodels\miscmodels\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\miscmodels
#   creating build\lib.win-amd64-cpython-311\statsmodels\multivariate
#   copying statsmodels\multivariate\api.py -> build\lib.win-amd64-cpython-311\statsmodels\multivariate
#   copying statsmodels\multivariate\cancorr.py -> build\lib.win-amd64-cpython-311\statsmodels\multivariate
#   copying statsmodels\multivariate\factor.py -> build\lib.win-amd64-cpython-311\statsmodels\multivariate
#   copying statsmodels\multivariate\manova.py -> build\lib.win-amd64-cpython-311\statsmodels\multivariate
#   copying statsmodels\multivariate\multivariate_ols.py -> build\lib.win-amd64-cpython-311\statsmodels\multivariate
#   copying statsmodels\multivariate\pca.py -> build\lib.win-amd64-cpython-311\statsmodels\multivariate
#   copying statsmodels\multivariate\plots.py -> build\lib.win-amd64-cpython-311\statsmodels\multivariate
#   copying statsmodels\multivariate\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\multivariate
#   creating build\lib.win-amd64-cpython-311\statsmodels\nonparametric
#   copying statsmodels\nonparametric\api.py -> build\lib.win-amd64-cpython-311\statsmodels\nonparametric
#   copying statsmodels\nonparametric\bandwidths.py -> build\lib.win-amd64-cpython-311\statsmodels\nonparametric
#   copying statsmodels\nonparametric\kde.py -> build\lib.win-amd64-cpython-311\statsmodels\nonparametric
#   copying statsmodels\nonparametric\kdetools.py -> build\lib.win-amd64-cpython-311\statsmodels\nonparametric
#   copying statsmodels\nonparametric\kernels.py -> build\lib.win-amd64-cpython-311\statsmodels\nonparametric
#   copying statsmodels\nonparametric\kernel_density.py -> build\lib.win-amd64-cpython-311\statsmodels\nonparametric
#   copying statsmodels\nonparametric\kernel_regression.py -> build\lib.win-amd64-cpython-311\statsmodels\nonparametric
#   copying statsmodels\nonparametric\smoothers_lowess.py -> build\lib.win-amd64-cpython-311\statsmodels\nonparametric
#   copying statsmodels\nonparametric\smoothers_lowess_old.py -> build\lib.win-amd64-cpython-311\statsmodels\nonparametric
#   copying statsmodels\nonparametric\_kernel_base.py -> build\lib.win-amd64-cpython-311\statsmodels\nonparametric
#   copying statsmodels\nonparametric\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\nonparametric
#   creating build\lib.win-amd64-cpython-311\statsmodels\regression
#   copying statsmodels\regression\dimred.py -> build\lib.win-amd64-cpython-311\statsmodels\regression
#   copying statsmodels\regression\feasible_gls.py -> build\lib.win-amd64-cpython-311\statsmodels\regression
#   copying statsmodels\regression\linear_model.py -> build\lib.win-amd64-cpython-311\statsmodels\regression
#   copying statsmodels\regression\mixed_linear_model.py -> build\lib.win-amd64-cpython-311\statsmodels\regression
#   copying statsmodels\regression\process_regression.py -> build\lib.win-amd64-cpython-311\statsmodels\regression
#   copying statsmodels\regression\quantile_regression.py -> build\lib.win-amd64-cpython-311\statsmodels\regression
#   copying statsmodels\regression\recursive_ls.py -> build\lib.win-amd64-cpython-311\statsmodels\regression
#   copying statsmodels\regression\_prediction.py -> build\lib.win-amd64-cpython-311\statsmodels\regression
#   copying statsmodels\regression\_tools.py -> build\lib.win-amd64-cpython-311\statsmodels\regression
#   copying statsmodels\regression\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\regression
#   creating build\lib.win-amd64-cpython-311\statsmodels\resampling
#   copying statsmodels\resampling\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\resampling
#   creating build\lib.win-amd64-cpython-311\statsmodels\robust
#   copying statsmodels\robust\norms.py -> build\lib.win-amd64-cpython-311\statsmodels\robust
#   copying statsmodels\robust\robust_linear_model.py -> build\lib.win-amd64-cpython-311\statsmodels\robust
#   copying statsmodels\robust\scale.py -> build\lib.win-amd64-cpython-311\statsmodels\robust
#   copying statsmodels\robust\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\robust
#   creating build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   copying statsmodels\sandbox\bspline.py -> build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   copying statsmodels\sandbox\contrast_old.py -> build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   copying statsmodels\sandbox\descstats.py -> build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   copying statsmodels\sandbox\formula.py -> build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   copying statsmodels\sandbox\gam.py -> build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   copying statsmodels\sandbox\infotheo.py -> build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   copying statsmodels\sandbox\mle.py -> build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   copying statsmodels\sandbox\multilinear.py -> build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   copying statsmodels\sandbox\pca.py -> build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   copying statsmodels\sandbox\predict_functional.py -> build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   copying statsmodels\sandbox\rls.py -> build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   copying statsmodels\sandbox\sysreg.py -> build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   copying statsmodels\sandbox\utils_old.py -> build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   copying statsmodels\sandbox\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\sandbox
#   creating build\lib.win-amd64-cpython-311\statsmodels\src
#   copying statsmodels\src\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\src
#   creating build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\anova.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\api.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\base.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\contingency_tables.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\contrast.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\correlation_tools.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\descriptivestats.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\diagnostic.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\gof.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\inter_rater.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\knockoff_regeffects.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\mediation.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\moment_helpers.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\multicomp.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\multitest.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\multivariate_tools.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\outliers_influence.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\power.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\proportion.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\regularized_covariance.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\sandwich_covariance.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\stattools.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\tabledist.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\weightstats.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\_adnorm.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\_diagnostic_other.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\_knockoff.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\_lilliefors.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   copying statsmodels\stats\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\stats
#   creating build\lib.win-amd64-cpython-311\statsmodels\tests
#   copying statsmodels\tests\test_package.py -> build\lib.win-amd64-cpython-311\statsmodels\tests
#   copying statsmodels\tests\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\tests
#   creating build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\catadd.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\data.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\decorators.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\eval_measures.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\grouputils.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\linalg.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\numdiff.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\parallel.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\print_version.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\rootfinding.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\sequences.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\sm_exceptions.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\testing.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\tools.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\transform_model.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\web.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\_testing.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   copying statsmodels\tools\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\tools
#   creating build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\adfvalues.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\api.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\arima_model.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\arima_process.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\arma_mle.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\ar_model.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\coint_tables.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\descriptivestats.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\holtwinters.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\mlemodel.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\seasonal.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\stattools.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\tsatools.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\varma_process.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\x13.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\_bds.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   copying statsmodels\tsa\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\tsa
#   creating build\lib.win-amd64-cpython-311\statsmodels\base\tests
#   copying statsmodels\base\tests\test_data.py -> build\lib.win-amd64-cpython-311\statsmodels\base\tests
#   copying statsmodels\base\tests\test_distributed_estimation.py -> build\lib.win-amd64-cpython-311\statsmodels\base\tests
#   copying statsmodels\base\tests\test_generic_methods.py -> build\lib.win-amd64-cpython-311\statsmodels\base\tests
#   copying statsmodels\base\tests\test_optimize.py -> build\lib.win-amd64-cpython-311\statsmodels\base\tests
#   copying statsmodels\base\tests\test_penalized.py -> build\lib.win-amd64-cpython-311\statsmodels\base\tests
#   copying statsmodels\base\tests\test_penalties.py -> build\lib.win-amd64-cpython-311\statsmodels\base\tests
#   copying statsmodels\base\tests\test_predict.py -> build\lib.win-amd64-cpython-311\statsmodels\base\tests
#   copying statsmodels\base\tests\test_screening.py -> build\lib.win-amd64-cpython-311\statsmodels\base\tests
#   copying statsmodels\base\tests\test_shrink_pickle.py -> build\lib.win-amd64-cpython-311\statsmodels\base\tests
#   copying statsmodels\base\tests\test_transform.py -> build\lib.win-amd64-cpython-311\statsmodels\base\tests
#   copying statsmodels\base\tests\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\base\tests
#   creating build\lib.win-amd64-cpython-311\statsmodels\compat\tests
#   copying statsmodels\compat\tests\test_itercompat.py -> build\lib.win-amd64-cpython-311\statsmodels\compat\tests
#   copying statsmodels\compat\tests\test_scipy_compat.py -> build\lib.win-amd64-cpython-311\statsmodels\compat\tests
#   copying statsmodels\compat\tests\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\compat\tests
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\anes96
#   copying statsmodels\datasets\anes96\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\anes96
#   copying statsmodels\datasets\anes96\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\anes96
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\cancer
#   copying statsmodels\datasets\cancer\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\cancer
#   copying statsmodels\datasets\cancer\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\cancer
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\ccard
#   copying statsmodels\datasets\ccard\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\ccard
#   copying statsmodels\datasets\ccard\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\ccard
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\china_smoking
#   copying statsmodels\datasets\china_smoking\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\china_smoking
#   copying statsmodels\datasets\china_smoking\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\china_smoking
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\co2
#   copying statsmodels\datasets\co2\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\co2
#   copying statsmodels\datasets\co2\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\co2
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\committee
#   copying statsmodels\datasets\committee\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\committee
#   copying statsmodels\datasets\committee\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\committee
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\copper
#   copying statsmodels\datasets\copper\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\copper
#   copying statsmodels\datasets\copper\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\copper
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\cpunish
#   copying statsmodels\datasets\cpunish\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\cpunish
#   copying statsmodels\datasets\cpunish\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\cpunish
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\elnino
#   copying statsmodels\datasets\elnino\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\elnino
#   copying statsmodels\datasets\elnino\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\elnino
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\engel
#   copying statsmodels\datasets\engel\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\engel
#   copying statsmodels\datasets\engel\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\engel
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\fair
#   copying statsmodels\datasets\fair\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\fair
#   copying statsmodels\datasets\fair\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\fair
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\fertility
#   copying statsmodels\datasets\fertility\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\fertility
#   copying statsmodels\datasets\fertility\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\fertility
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\grunfeld
#   copying statsmodels\datasets\grunfeld\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\grunfeld
#   copying statsmodels\datasets\grunfeld\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\grunfeld
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\heart
#   copying statsmodels\datasets\heart\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\heart
#   copying statsmodels\datasets\heart\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\heart
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\interest_inflation
#   copying statsmodels\datasets\interest_inflation\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\interest_inflation
#   copying statsmodels\datasets\interest_inflation\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\interest_inflation
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\longley
#   copying statsmodels\datasets\longley\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\longley
#   copying statsmodels\datasets\longley\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\longley
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\macrodata
#   copying statsmodels\datasets\macrodata\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\macrodata
#   copying statsmodels\datasets\macrodata\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\macrodata
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\modechoice
#   copying statsmodels\datasets\modechoice\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\modechoice
#   copying statsmodels\datasets\modechoice\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\modechoice
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\nile
#   copying statsmodels\datasets\nile\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\nile
#   copying statsmodels\datasets\nile\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\nile
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\randhie
#   copying statsmodels\datasets\randhie\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\randhie
#   copying statsmodels\datasets\randhie\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\randhie
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\scotland
#   copying statsmodels\datasets\scotland\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\scotland
#   copying statsmodels\datasets\scotland\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\scotland
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\spector
#   copying statsmodels\datasets\spector\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\spector
#   copying statsmodels\datasets\spector\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\spector
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\stackloss
#   copying statsmodels\datasets\stackloss\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\stackloss
#   copying statsmodels\datasets\stackloss\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\stackloss
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\star98
#   copying statsmodels\datasets\star98\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\star98
#   copying statsmodels\datasets\star98\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\star98
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\statecrime
#   copying statsmodels\datasets\statecrime\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\statecrime
#   copying statsmodels\datasets\statecrime\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\statecrime
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\strikes
#   copying statsmodels\datasets\strikes\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\strikes
#   copying statsmodels\datasets\strikes\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\strikes
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\sunspots
#   copying statsmodels\datasets\sunspots\data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\sunspots
#   copying statsmodels\datasets\sunspots\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\sunspots
#   creating build\lib.win-amd64-cpython-311\statsmodels\datasets\tests
#   copying statsmodels\datasets\tests\test_data.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\tests
#   copying statsmodels\datasets\tests\test_utils.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\tests
#   copying statsmodels\datasets\tests\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\datasets\tests
#   creating build\lib.win-amd64-cpython-311\statsmodels\discrete\tests
#   copying statsmodels\discrete\tests\test_conditional.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete\tests
#   copying statsmodels\discrete\tests\test_constrained.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete\tests
#   copying statsmodels\discrete\tests\test_count_model.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete\tests
#   copying statsmodels\discrete\tests\test_diagnostic.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete\tests
#   copying statsmodels\discrete\tests\test_discrete.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete\tests
#   copying statsmodels\discrete\tests\test_margins.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete\tests
#   copying statsmodels\discrete\tests\test_sandwich_cov.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete\tests
#   copying statsmodels\discrete\tests\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete\tests
#   creating build\lib.win-amd64-cpython-311\statsmodels\discrete\tests\results
#   copying statsmodels\discrete\tests\results\results_count_margins.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete\tests\results
#   copying statsmodels\discrete\tests\results\results_count_robust_cluster.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete\tests\results
#   copying statsmodels\discrete\tests\results\results_discrete.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete\tests\results
#   copying statsmodels\discrete\tests\results\results_glm_logit_constrained.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete\tests\results
#   copying statsmodels\discrete\tests\results\results_poisson_constrained.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete\tests\results
#   copying statsmodels\discrete\tests\results\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\discrete\tests\results
#   creating build\lib.win-amd64-cpython-311\statsmodels\distributions\tests
#   copying statsmodels\distributions\tests\test_discrete.py -> build\lib.win-amd64-cpython-311\statsmodels\distributions\tests
#   copying statsmodels\distributions\tests\test_ecdf.py -> build\lib.win-amd64-cpython-311\statsmodels\distributions\tests
#   copying statsmodels\distributions\tests\test_edgeworth.py -> build\lib.win-amd64-cpython-311\statsmodels\distributions\tests
#   copying statsmodels\distributions\tests\test_mixture.py -> build\lib.win-amd64-cpython-311\statsmodels\distributions\tests
#   copying statsmodels\distributions\tests\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\distributions\tests
#   creating build\lib.win-amd64-cpython-311\statsmodels\duration\tests
#   copying statsmodels\duration\tests\test_phreg.py -> build\lib.win-amd64-cpython-311\statsmodels\duration\tests
#   copying statsmodels\duration\tests\test_survfunc.py -> build\lib.win-amd64-cpython-311\statsmodels\duration\tests
#   copying statsmodels\duration\tests\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\duration\tests
#   creating build\lib.win-amd64-cpython-311\statsmodels\duration\tests\results
#   copying statsmodels\duration\tests\results\phreg_gentests.py -> build\lib.win-amd64-cpython-311\statsmodels\duration\tests\results
#   copying statsmodels\duration\tests\results\survival_enet_r_results.py -> build\lib.win-amd64-cpython-311\statsmodels\duration\tests\results
#   copying statsmodels\duration\tests\results\survival_r_results.py -> build\lib.win-amd64-cpython-311\statsmodels\duration\tests\results
#   copying statsmodels\duration\tests\results\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\duration\tests\results
#   creating build\lib.win-amd64-cpython-311\statsmodels\emplike\tests
#   copying statsmodels\emplike\tests\test_aft.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike\tests
#   copying statsmodels\emplike\tests\test_anova.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike\tests
#   copying statsmodels\emplike\tests\test_descriptive.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike\tests
#   copying statsmodels\emplike\tests\test_origin.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike\tests
#   copying statsmodels\emplike\tests\test_regression.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike\tests
#   copying statsmodels\emplike\tests\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike\tests
#   creating build\lib.win-amd64-cpython-311\statsmodels\emplike\tests\results
#   copying statsmodels\emplike\tests\results\el_results.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike\tests\results
#   copying statsmodels\emplike\tests\results\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\emplike\tests\results
#   creating build\lib.win-amd64-cpython-311\statsmodels\formula\tests
#   copying statsmodels\formula\tests\test_formula.py -> build\lib.win-amd64-cpython-311\statsmodels\formula\tests
#   copying statsmodels\formula\tests\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\formula\tests
#   creating build\lib.win-amd64-cpython-311\statsmodels\gam\gam_cross_validation
#   copying statsmodels\gam\gam_cross_validation\cross_validators.py -> build\lib.win-amd64-cpython-311\statsmodels\gam\gam_cross_validation
#   copying statsmodels\gam\gam_cross_validation\gam_cross_validation.py -> build\lib.win-amd64-cpython-311\statsmodels\gam\gam_cross_validation
#   copying statsmodels\gam\gam_cross_validation\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\gam\gam_cross_validation
#   creating build\lib.win-amd64-cpython-311\statsmodels\gam\tests
#   copying statsmodels\gam\tests\test_gam.py -> build\lib.win-amd64-cpython-311\statsmodels\gam\tests
#   copying statsmodels\gam\tests\test_penalized.py -> build\lib.win-amd64-cpython-311\statsmodels\gam\tests
#   copying statsmodels\gam\tests\test_smooth_basis.py -> build\lib.win-amd64-cpython-311\statsmodels\gam\tests
#   copying statsmodels\gam\tests\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\gam\tests
#   creating build\lib.win-amd64-cpython-311\statsmodels\gam\tests\results
#   copying statsmodels\gam\tests\results\results_mpg_bs.py -> build\lib.win-amd64-cpython-311\statsmodels\gam\tests\results
#   copying statsmodels\gam\tests\results\results_mpg_bs_poisson.py -> build\lib.win-amd64-cpython-311\statsmodels\gam\tests\results
#   copying statsmodels\gam\tests\results\results_pls.py -> build\lib.win-amd64-cpython-311\statsmodels\gam\tests\results
#   copying statsmodels\gam\tests\results\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\gam\tests\results
#   creating build\lib.win-amd64-cpython-311\statsmodels\genmod\families
#   copying statsmodels\genmod\families\family.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod\families
#   copying statsmodels\genmod\families\links.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod\families
#   copying statsmodels\genmod\families\varfuncs.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod\families
#   copying statsmodels\genmod\families\__init__.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod\families
#   creating build\lib.win-amd64-cpython-311\statsmodels\genmod\tests
#   copying statsmodels\genmod\tests\gee_categorical_simulation_check.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod\tests
#   copying statsmodels\genmod\tests\gee_gaussian_simulation_check.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod\tests
#   copying statsmodels\genmod\tests\gee_poisson_simulation_check.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod\tests
#   copying statsmodels\genmod\tests\gee_simulation_check.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod\tests
#   copying statsmodels\genmod\tests\test_bayes_mixed_glm.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod\tests
#   copying statsmodels\genmod\tests\test_constrained.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod\tests
#   copying statsmodels\genmod\tests\test_gee.py -> build\lib.win-amd64-cpython-311\statsmodels\genmod\tests
# ...
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_colo_fc5.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_colo_granger_causality_dp_r.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_colo_granger_causality_r_dp.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_colo_inst_causality_dp_r.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_colo_inst_causality_r_dp.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_colo_ir.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_colo_lagorder.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_colo_Sigmau.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_cos.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_coslo.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_coslo_diag.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_coslo_fc5.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_coslo_granger_causality_dp_r.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_coslo_granger_causality_r_dp.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_coslo_inst_causality_dp_r.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_coslo_inst_causality_r_dp.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_coslo_ir.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_coslo_lagorder.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_coslo_Sigmau.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_cos_diag.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_cos_fc5.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_cos_granger_causality_dp_r.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_cos_granger_causality_r_dp.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_cos_inst_causality_dp_r.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_cos_inst_causality_r_dp.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_cos_ir.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_cos_lagorder.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_cos_Sigmau.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_co_diag.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_co_fc5.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_co_granger_causality_dp_r.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_co_granger_causality_r_dp.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_co_inst_causality_dp_r.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_co_inst_causality_r_dp.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_co_ir.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_co_lagorder.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_co_Sigmau.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_nc.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_ncs.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_ncs_diag.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_ncs_fc5.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_ncs_granger_causality_dp_r.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_ncs_granger_causality_r_dp.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_ncs_inst_causality_dp_r.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_ncs_inst_causality_r_dp.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_ncs_ir.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_ncs_lagorder.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_ncs_Sigmau.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_nc_diag.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_nc_fc5.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_nc_granger_causality_dp_r.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_nc_granger_causality_r_dp.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_nc_inst_causality_dp_r.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_nc_inst_causality_r_dp.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_nc_ir.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_nc_lagorder.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\JMulTi_results\vecm_e6_jmulti_nc_Sigmau.txt -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\JMulTi_results
#   copying statsmodels\tsa\vector_ar\tests\Matlab_results\test_coint.csv -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\Matlab_results
#   copying statsmodels\tsa\vector_ar\tests\results\vars_results.npz -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\results
#   copying statsmodels\tsa\vector_ar\tests\results\e1.dat -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\results
#   copying statsmodels\tsa\vector_ar\tests\results\e2.dat -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\results
#   copying statsmodels\tsa\vector_ar\tests\results\e3.dat -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\results
#   copying statsmodels\tsa\vector_ar\tests\results\e4.dat -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\results
#   copying statsmodels\tsa\vector_ar\tests\results\e5.dat -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\results
#   copying statsmodels\tsa\vector_ar\tests\results\e6.dat -> build\lib.win-amd64-cpython-311\statsmodels\tsa\vector_ar\tests\results
#   UPDATING build\lib.win-amd64-cpython-311\statsmodels/_version.py
#   set build\lib.win-amd64-cpython-311\statsmodels/_version.py to '0.10.1'
#   running build_ext
#   C:\Users\61723\AppData\Local\Temp\pip-install-2eiu8097\statsmodels_ed9dbf2378954d7e92d2d01ffc125b59\setup.py:201: DeprecationWarning:
#
#     `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#     of the deprecation of `distutils` itself. It will be removed for
#     Python >= 3.12. For older Python versions it will remain present.
#     It is recommended to use `setuptools < 60.0` for those Python versions.
#     For more details, see:
#       https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#     from numpy.distutils.misc_util import get_info
#   error: Command "C:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.33.31629\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -DCYTHON_TRACE_NOGIL=0 -ID:\anaconda\Lib\site-packages\numpy\core\include -ID:\\anaconda\\Lib\\site-packages\\numpy\\core\\include -ID:\anaconda\include -ID:\anaconda\Include -IC:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.33.31629\include -IC:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.33.31629\ATLMFC\include -IC:\Program Files\Microsoft Visual Studio\2022\Community\VC\Auxiliary\VS\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\cppwinrt /Tcstatsmodels/tsa/_exponential_smoothers.c /Fobuild\temp.win-amd64-cpython-311\Release\statsmodels\tsa\_exponential_smoothers.obj" failed with exit status 2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for statsmodels
#   error: subprocess-exited-with-error
#
#   python setup.py clean did not run successfully.
#   exit code: 1
#
#   [42 lines of output]
#   C:\Users\61723\AppData\Local\Temp\pip-install-2eiu8097\statsmodels_ed9dbf2378954d7e92d2d01ffc125b59\setup.py:14: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#     import pkg_resources
#   C:\Users\61723\AppData\Local\Temp\pip-install-2eiu8097\statsmodels_ed9dbf2378954d7e92d2d01ffc125b59\setup.py:50: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     req_ver = LooseVersion(SETUP_REQUIREMENTS[key])
#   C:\Users\61723\AppData\Local\Temp\pip-install-2eiu8097\statsmodels_ed9dbf2378954d7e92d2d01ffc125b59\setup.py:53: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     ver = LooseVersion(mod.__version__)
#   C:\Users\61723\AppData\Local\Temp\pip-install-2eiu8097\statsmodels_ed9dbf2378954d7e92d2d01ffc125b59\setup.py:50: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     req_ver = LooseVersion(SETUP_REQUIREMENTS[key])
#   D:\anaconda\Lib\site-packages\setuptools\config\setupcfg.py:293: _DeprecatedConfig: Deprecated config in `setup.cfg`
#   !!
#
#           ********************************************************************************
#           The license_file parameter is deprecated, use license_files instead.
#
#           This deprecation is overdue, please update your project and remove deprecated
#           calls to avoid build errors in the future.
#
#           See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#           ********************************************************************************
#
#   !!
#     parsed = self.parsers.get(option_name, lambda x: x)(value)
#   D:\anaconda\Lib\site-packages\setuptools\__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#   !!
#
#           ********************************************************************************
#           Requirements should be satisfied by a PEP 517 installer.
#           If you are using pip, you can try `pip install --use-pep517`.
#           ********************************************************************************
#
#   !!
#     dist.fetch_build_eggs(dist.setup_requires)
#   running clean
#
#
#   python setup.py clean is not supported.
#
#   Use one of:
#
#   * `git clean -xdf` to clean all untracked files
#   * `git clean -Xdf` to clean untracked files ignored by .gitignore
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed cleaning build dir for statsmodels
# ERROR: Could not build wheels for statsmodels, which is required to install pyproject.toml-based projects

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import datetime
import statsmodels.api as sm
from pylab import rcParams
from datetime import datetime
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf,month_plot,quarter_plot

rcParams['figure.figsize'] = 18, 10

# %%
import tensorflow as tf
import random as python_random

def reset_seeds():
  python_random.seed(49)
  np.random.seed(49) 
  tf.random.set_seed(49)

reset_seeds()
# Out:
# WARNING:tensorflow:From D:\anaconda\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df=pd.read_csv('C:/Users/61723/Desktop/Coal Price Prediction.csv')
df.Date = pd.to_datetime(df.Date, dayfirst=True)
df = df.sort_values(by='Date')
df = df.set_index('Date')
df.index=pd.to_datetime(df.index.strftime("%Y-%d-%m"))

# %%
df.head()
# Out:
#             Colombia coal price  Global coal price  Crude Oil  Diesel  \
# Date
# 2007-01-01                51.19              51.29      53.52    1.63
# 2007-02-01                52.70              52.90      57.56    1.76
# 2007-03-01                53.59              55.38      60.60    1.89
# 2007-04-01                51.94              56.12      65.06    2.05
# 2007-05-01                51.30              56.00      65.16    2.04
#
#             Gasoline  Natural Gas  Coal Producer Index    Gold  Silver  \
# Date
# 2007-01-01      1.43         6.58                138.8  631.17   12.84
# 2007-02-01      1.64         7.97                139.9  664.75   13.91
# 2007-03-01      1.94         7.12                142.1  654.90   13.18
# 2007-04-01      2.11         7.59                141.6  679.37   13.72
# 2007-05-01      2.25         7.61                140.2  667.31   13.15
#
#              Copper  Iron Ore  Crude Oil Index  Metal Index  Non-Fuel Index  \
# Date
# 2007-01-01  5669.66     78.20           116.85        96.83           80.64
# 2007-02-01  5676.45     82.66           124.72        98.69           82.68
# 2007-03-01  6452.48     88.55           130.38       104.59           84.65
# 2007-04-01  7766.47     91.26           138.96       114.38           87.98
# 2007-05-01  7681.42    102.02           139.33       116.38           89.71
#
#             Commodity Index  Consumer confidence index  \
# Date
# 2007-01-01            73.21                     101.14
# 2007-02-01            79.39                     101.08
# 2007-03-01            81.55                     101.00
# 2007-04-01            86.79                     100.98
# 2007-05-01            86.92                     101.00
#
#             Business confidence index
# Date
# 2007-01-01                     100.95
# 2007-02-01                     101.02
# 2007-03-01                     101.07
# 2007-04-01                     101.09
# 2007-05-01                     101.09

# %%
# Checking number of NaN values
nan_values_array = []
for column in df:
     nan_values_array.append(df[column].isnull().sum())
     
column_names = list(df.columns.values)
data = {'Feature':column_names,'Number of NaN values':nan_values_array}
nan_values = pd.DataFrame(data)
print(nan_values)
# Out:
#                       Feature  Number of NaN values
# 0         Colombia coal price                     0
# 1           Global coal price                     0
# 2                   Crude Oil                     0
# 3                      Diesel                     0
# 4                    Gasoline                     0
# 5                 Natural Gas                     0
# 6         Coal Producer Index                     0
# 7                        Gold                     0
# 8                      Silver                     0
# 9                      Copper                     0
# 10                   Iron Ore                     0
# 11            Crude Oil Index                     0
# 12                Metal Index                     0
# 13             Non-Fuel Index                     0
# 14            Commodity Index                     0
# 15  Consumer confidence index                     0
# 16  Business confidence index                     0

# %%
#Default of this method is 'Pearson'
df.corr()
# Out:
#                            Colombia coal price  Global coal price  Crude Oil  \
# Colombia coal price                   1.000000           0.945169   0.616003
# Global coal price                     0.945169           1.000000   0.643826
# Crude Oil                             0.616003           0.643826   1.000000
# Diesel                                0.646513           0.649234   0.984334
# Gasoline                              0.557782           0.579500   0.975603
# Natural Gas                           0.499044           0.422633   0.360217
# Coal Producer Index                   0.022990           0.122901   0.217329
# Gold                                  0.165402           0.257209   0.393097
# Silver                                0.428600           0.480339   0.626702
# Copper                                0.580685           0.643363   0.808229
# Iron Ore                              0.720831           0.748662   0.807661
# Crude Oil Index                       0.592989           0.622281   0.995438
# Metal Index                           0.630448           0.653745   0.735818
# Non-Fuel Index                        0.747743           0.775497   0.890749
# Commodity Index                       0.663855           0.680869   0.994192
# Consumer confidence index            -0.541523          -0.533166  -0.456354
# Business confidence index             0.042781           0.084169   0.155853
#
#                              Diesel  Gasoline  Natural Gas  \
# Colombia coal price        0.646513  0.557782     0.499044
# Global coal price          0.649234  0.579500     0.422633
# Crude Oil                  0.984334  0.975603     0.360217
# Diesel                     1.000000  0.969020     0.392864
# Gasoline                   0.969020  1.000000     0.275445
# Natural Gas                0.392864  0.275445     1.000000
# Coal Producer Index        0.202151  0.260227    -0.688016
# Gold                       0.392082  0.458292    -0.589985
# Silver                     0.619839  0.672673    -0.251086
# Copper                     0.799010  0.822693     0.276354
# Iron Ore                   0.790095  0.744460     0.515792
# Crude Oil Index            0.982096  0.980984     0.307782
# Metal Index                0.731855  0.720967     0.549593
# Non-Fuel Index             0.888983  0.873045     0.323319
# Commodity Index            0.985239  0.959243     0.448934
# Consumer confidence index -0.444402 -0.356033    -0.285642
# Business confidence index  0.162404  0.230220    -0.038574
#
#                            Coal Producer Index      Gold    Silver    Copper  \
# Colombia coal price                   0.022990  0.165402  0.428600  0.580685
# Global coal price                     0.122901  0.257209  0.480339  0.643363
# Crude Oil                             0.217329  0.393097  0.626702  0.808229
# Diesel                                0.202151  0.392082  0.619839  0.799010
# Gasoline                              0.260227  0.458292  0.672673  0.822693
# Natural Gas                          -0.688016 -0.589985 -0.251086  0.276354
# Coal Producer Index                   1.000000  0.860086  0.594892  0.108131
# Gold                                  0.860086  1.000000  0.849834  0.387328
# Silver                                0.594892  0.849834  1.000000  0.684784
# Copper                                0.108131  0.387328  0.684784  1.000000
# Iron Ore                             -0.079704  0.175146  0.519789  0.816801
# Crude Oil Index                       0.267952  0.435323  0.636936  0.801278
# Metal Index                          -0.226852  0.089238  0.488719  0.926818
# Non-Fuel Index                        0.220513  0.464090  0.766992  0.906074
# Commodity Index                       0.147481  0.321404  0.579401  0.797015
# Consumer confidence index            -0.169333 -0.123482 -0.288226 -0.130837
# Business confidence index            -0.012903  0.203360  0.227096  0.511643
#
#                            Iron Ore  Crude Oil Index  Metal Index  \
# Colombia coal price        0.720831         0.592989     0.630448
# Global coal price          0.748662         0.622281     0.653745
# Crude Oil                  0.807661         0.995438     0.735818
# Diesel                     0.790095         0.982096     0.731855
# Gasoline                   0.744460         0.980984     0.720967
# Natural Gas                0.515792         0.307782     0.549593
# Coal Producer Index       -0.079704         0.267952    -0.226852
# Gold                       0.175146         0.435323     0.089238
# Silver                     0.519789         0.636936     0.488719
# Copper                     0.816801         0.801278     0.926818
# Iron Ore                   1.000000         0.777204     0.880394
# Crude Oil Index            0.777204         1.000000     0.708832
# Metal Index                0.880394         0.708832     1.000000
# Non-Fuel Index             0.875285         0.873813     0.840974
# Commodity Index            0.830027         0.984068     0.755949
# Consumer confidence index -0.439964        -0.415247    -0.148097
# Business confidence index  0.208561         0.188047     0.465706
#
#                            Non-Fuel Index  Commodity Index  \
# Colombia coal price              0.747743         0.663855
# Global coal price                0.775497         0.680869
# Crude Oil                        0.890749         0.994192
# Diesel                           0.888983         0.985239
# Gasoline                         0.873045         0.959243
# Natural Gas                      0.323319         0.448934
# Coal Producer Index              0.220513         0.147481
# Gold                             0.464090         0.321404
# Silver                           0.766992         0.579401
# Copper                           0.906074         0.797015
# Iron Ore                         0.875285         0.830027
# Crude Oil Index                  0.873813         0.984068
# Metal Index                      0.840974         0.755949
# Non-Fuel Index                   1.000000         0.891467
# Commodity Index                  0.891467         1.000000
# Consumer confidence index       -0.455008        -0.494405
# Business confidence index        0.235091         0.121670
#
#                            Consumer confidence index  \
# Colombia coal price                        -0.541523
# Global coal price                          -0.533166
# Crude Oil                                  -0.456354
# Diesel                                     -0.444402
# Gasoline                                   -0.356033
# Natural Gas                                -0.285642
# Coal Producer Index                        -0.169333
# Gold                                       -0.123482
# Silver                                     -0.288226
# Copper                                     -0.130837
# Iron Ore                                   -0.439964
# Crude Oil Index                            -0.415247
# Metal Index                                -0.148097
# Non-Fuel Index                             -0.455008
# Commodity Index                            -0.494405
# Consumer confidence index                   1.000000
# Business confidence index                   0.722290
#
#                            Business confidence index
# Colombia coal price                         0.042781
# Global coal price                           0.084169
# Crude Oil                                   0.155853
# Diesel                                      0.162404
# Gasoline                                    0.230220
# Natural Gas                                -0.038574
# Coal Producer Index                        -0.012903
# Gold                                        0.203360
# Silver                                      0.227096
# Copper                                      0.511643
# Iron Ore                                    0.208561
# Crude Oil Index                             0.188047
# Metal Index                                 0.465706
# Non-Fuel Index                              0.235091
# Commodity Index                             0.121670
# Consumer confidence index                   0.722290
# Business confidence index                   1.000000

# %%
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn").set_title("Correlation Heat Map (Pearson)")

# %%
df.corr(method='spearman')
# Out:
#                            Colombia coal price  Global coal price  Crude Oil  \
# Colombia coal price                   1.000000           0.917819   0.589726
# Global coal price                     0.917819           1.000000   0.612083
# Crude Oil                             0.589726           0.612083   1.000000
# Diesel                                0.632483           0.630810   0.973405
# Gasoline                              0.559765           0.568368   0.967733
# Natural Gas                           0.319529           0.297157   0.370464
# Coal Producer Index                   0.258937           0.245586   0.447364
# Gold                                  0.343569           0.370206   0.426352
# Silver                                0.486454           0.546055   0.660482
# Copper                                0.628264           0.675009   0.823630
# Iron Ore                              0.723901           0.752496   0.803855
# Crude Oil Index                       0.575838           0.592263   0.991194
# Metal Index                           0.605149           0.639149   0.733520
# Non-Fuel Index                        0.713364           0.741418   0.911988
# Commodity Index                       0.631179           0.642653   0.989787
# Consumer confidence index            -0.505928          -0.534427  -0.512527
# Business confidence index             0.121451           0.059209  -0.011901
#
#                              Diesel  Gasoline  Natural Gas  \
# Colombia coal price        0.632483  0.559765     0.319529
# Global coal price          0.630810  0.568368     0.297157
# Crude Oil                  0.973405  0.967733     0.370464
# Diesel                     1.000000  0.959831     0.384155
# Gasoline                   0.959831  1.000000     0.315969
# Natural Gas                0.384155  0.315969     1.000000
# Coal Producer Index        0.443512  0.484571    -0.449609
# Gold                       0.419478  0.470725    -0.450695
# Silver                     0.642602  0.669354    -0.160147
# Copper                     0.846982  0.837354     0.342529
# Iron Ore                   0.808133  0.766946     0.567233
# Crude Oil Index            0.966915  0.971830     0.328367
# Metal Index                0.754768  0.734089     0.560907
# Non-Fuel Index             0.918678  0.905934     0.356302
# Commodity Index            0.977076  0.953702     0.443031
# Consumer confidence index -0.505633 -0.446154    -0.263965
# Business confidence index -0.025352  0.012988     0.138510
#
#                            Coal Producer Index      Gold    Silver    Copper  \
# Colombia coal price                   0.258937  0.343569  0.486454  0.628264
# Global coal price                     0.245586  0.370206  0.546055  0.675009
# Crude Oil                             0.447364  0.426352  0.660482  0.823630
# Diesel                                0.443512  0.419478  0.642602  0.846982
# Gasoline                              0.484571  0.470725  0.669354  0.837354
# Natural Gas                          -0.449609 -0.450695 -0.160147  0.342529
# Coal Producer Index                   1.000000  0.891188  0.789981  0.340895
# Gold                                  0.891188  1.000000  0.903779  0.416471
# Silver                                0.789981  0.903779  1.000000  0.646810
# Copper                                0.340895  0.416471  0.646810  1.000000
# Iron Ore                              0.139748  0.211387  0.508719  0.853391
# Crude Oil Index                       0.490529  0.455845  0.671368  0.805461
# Metal Index                           0.053513  0.146718  0.434517  0.919862
# Non-Fuel Index                        0.434800  0.493451  0.729351  0.927719
# Commodity Index                       0.391234  0.370908  0.614280  0.818633
# Consumer confidence index            -0.172039 -0.202116 -0.340975 -0.341358
# Business confidence index            -0.023420  0.034096  0.062464  0.220332
#
#                            Iron Ore  Crude Oil Index  Metal Index  \
# Colombia coal price        0.723901         0.575838     0.605149
# Global coal price          0.752496         0.592263     0.639149
# Crude Oil                  0.803855         0.991194     0.733520
# Diesel                     0.808133         0.966915     0.754768
# Gasoline                   0.766946         0.971830     0.734089
# Natural Gas                0.567233         0.328367     0.560907
# Coal Producer Index        0.139748         0.490529     0.053513
# Gold                       0.211387         0.455845     0.146718
# Silver                     0.508719         0.671368     0.434517
# Copper                     0.853391         0.805461     0.919862
# Iron Ore                   1.000000         0.780598     0.898555
# Crude Oil Index            0.780598         1.000000     0.701224
# Metal Index                0.898555         0.701224     1.000000
# Non-Fuel Index             0.884477         0.896105     0.845984
# Commodity Index            0.828379         0.975513     0.750153
# Consumer confidence index -0.512456        -0.478970    -0.255778
# Business confidence index  0.117794        -0.007845     0.326263
#
#                            Non-Fuel Index  Commodity Index  \
# Colombia coal price              0.713364         0.631179
# Global coal price                0.741418         0.642653
# Crude Oil                        0.911988         0.989787
# Diesel                           0.918678         0.977076
# Gasoline                         0.905934         0.953702
# Natural Gas                      0.356302         0.443031
# Coal Producer Index              0.434800         0.391234
# Gold                             0.493451         0.370908
# Silver                           0.729351         0.614280
# Copper                           0.927719         0.818633
# Iron Ore                         0.884477         0.828379
# Crude Oil Index                  0.896105         0.975513
# Metal Index                      0.845984         0.750153
# Non-Fuel Index                   1.000000         0.911943
# Commodity Index                  0.911943         1.000000
# Consumer confidence index       -0.517934        -0.550461
# Business confidence index        0.073262        -0.032019
#
#                            Consumer confidence index  \
# Colombia coal price                        -0.505928
# Global coal price                          -0.534427
# Crude Oil                                  -0.512527
# Diesel                                     -0.505633
# Gasoline                                   -0.446154
# Natural Gas                                -0.263965
# Coal Producer Index                        -0.172039
# Gold                                       -0.202116
# Silver                                     -0.340975
# Copper                                     -0.341358
# Iron Ore                                   -0.512456
# Crude Oil Index                            -0.478970
# Metal Index                                -0.255778
# Non-Fuel Index                             -0.517934
# Commodity Index                            -0.550461
# Consumer confidence index                   1.000000
# Business confidence index                   0.653016
#
#                            Business confidence index
# Colombia coal price                         0.121451
# Global coal price                           0.059209
# Crude Oil                                  -0.011901
# Diesel                                     -0.025352
# Gasoline                                    0.012988
# Natural Gas                                 0.138510
# Coal Producer Index                        -0.023420
# Gold                                        0.034096
# Silver                                      0.062464
# Copper                                      0.220332
# Iron Ore                                    0.117794
# Crude Oil Index                            -0.007845
# Metal Index                                 0.326263
# Non-Fuel Index                              0.073262
# Commodity Index                            -0.032019
# Consumer confidence index                   0.653016
# Business confidence index                   1.000000

# %%
corrmat_spearman = df.corr(method='spearman')
top_corr_features = corrmat_spearman.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn").set_title("Correlation Heat Map (Spearman)")

# %%
# Correlation with output variable
cor_target = abs(corrmat["Colombia coal price"])
# Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
print(relevant_features)
# Out:
# Colombia coal price          1.000000
# Global coal price            0.945169
# Crude Oil                    0.616003
# Diesel                       0.646513
# Gasoline                     0.557782
# Copper                       0.580685
# Iron Ore                     0.720831
# Crude Oil Index              0.592989
# Metal Index                  0.630448
# Non-Fuel Index               0.747743
# Commodity Index              0.663855
# Consumer confidence index    0.541523
# Name: Colombia coal price, dtype: float64

# %%
rf_df = df[['Global coal price','Crude Oil','Diesel','Gasoline', 'Copper','Iron Ore','Crude Oil Index','Metal Index','Non-Fuel Index','Commodity Index','Consumer confidence index']]
fig, ax = plt.subplots(figsize=(8,8))
h=sns.heatmap(rf_df.corr(),annot=True,cmap="RdYlGn",ax=ax).set_title("Correlation Heat Map")

# %%
#(crude oil,Diesel) (crude oil,gasoline) (crude oil,commodity index) (Diesel,gasoline)(Diesel,crude oil index)(Diesel, commodity index)(gasoline, crude oil index)(gasoline, commodity index)(copper, metal index)(copper,non-fuel index)(crude oil index, commodity index)

# %%
fig2,ax2 = plt.subplots(2,2)
sns.heatmap(df[['Crude Oil','Diesel','Colombia coal price']].corr(),ax=ax2[0][0],annot=True,cmap="RdYlGn").set_title('Crude oil vs. Diesel')
sns.heatmap(df[['Crude Oil','Gasoline','Colombia coal price']].corr(),ax=ax2[0][1],annot=True,cmap="RdYlGn").set_title('Crude oil vs. Gasoline')
sns.heatmap(df[['Diesel','Gasoline','Colombia coal price']].corr(),ax=ax2[1][1],annot=True,cmap="RdYlGn").set_title('Diesel vs. Gasoline')
sns.heatmap(df[['Crude Oil','Commodity Index','Colombia coal price']].corr(),ax=ax2[1][0],annot=True,cmap="RdYlGn").set_title('Crude oil vs. Commodity Index')
# Out:
# Text(0.5, 1.0, 'Crude oil vs. Commodity Index')

# %%
fig3,ax3 = plt.subplots(2,2)
sns.heatmap(df[['Diesel','Crude Oil Index','Colombia coal price']].corr(),ax=ax3[0][0],annot=True,cmap="RdYlGn").set_title('Diesel vs. Crude Oil Index')
sns.heatmap(df[['Diesel','Commodity Index','Colombia coal price']].corr(),ax=ax3[0][1],annot=True,cmap="RdYlGn").set_title('Diesel vs. Commodity Index')
sns.heatmap(df[['Gasoline','Crude Oil Index','Colombia coal price']].corr(),ax=ax3[1][0],annot=True,cmap="RdYlGn").set_title('Gasoline vs. Crude Oil Index')
sns.heatmap(df[['Gasoline','Commodity Index','Colombia coal price']].corr(),ax=ax3[1][1],annot=True,cmap="RdYlGn").set_title('Gasoline vs.Commodity Index')
# Out:
# Text(0.5, 1.0, 'Gasoline vs.Commodity Index')

# %%
fig4,ax4 = plt.subplots(2,2)
sns.heatmap(df[['Copper', 'Metal Index','Colombia coal price']].corr(),ax=ax4[0][0],annot=True,cmap="RdYlGn").set_title('Copper vs. Metal Index')
sns.heatmap(df[['Copper','Non-Fuel Index','Colombia coal price']].corr(),ax=ax4[0][1],annot=True,cmap="RdYlGn").set_title('Copper vs. Non-Fuel Index')
sns.heatmap(df[['Crude Oil Index','Commodity Index','Colombia coal price']].corr(),ax=ax4[1][0],annot=True,cmap="RdYlGn").set_title('Crude Oil Index vs.Commodity Index')
# Out:
# Text(0.5, 1.0, 'Crude Oil Index vs.Commodity Index')

# %%
df.shape
# Out:
# (132, 17)

# %%
df.drop(['Gasoline','Diesel','Crude Oil Index','Iron Ore','Copper','Crude Oil','Business confidence index','Natural Gas','Gold','Silver','Coal Producer Index','Consumer confidence index'], axis=1,inplace=True)
df.head()
df.shape
# Out:
# (132, 5)

# %%
df.columns
# Out:
# Index(['Colombia coal price', 'Global coal price', 'Metal Index',
#        'Non-Fuel Index', 'Commodity Index'],
#       dtype='object')

# %%
df["Colombia coal price"].plot(linewidth=0.7, color='red')
plt.legend(df[["Colombia coal price"]], loc ="upper left") 
plt.title("Time Series Plot for Colombia coal price")
plt.show()

# %%
plt.plot(df.index, df["Colombia coal price"], linewidth=0.5, color='red')
plt.plot(pd.Series.rolling(df["Colombia coal price"], 2).mean())
plt.legend(["Colombia coal price", "Rolling Mean: 2"], loc ="upper left") 
plt.title("Trend Plot for Colombia coal price")
plt.show()

# %%
df['Year'] = pd.DatetimeIndex(df.index).year
df['Month'] = pd.DatetimeIndex(df.index).month

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Month', fontsize = 12)
ax.set_ylabel('Seasonal Plot for Colombia coal price', fontsize = 12)
ax.set_title('Seasonal plot of Colombia coal price', fontsize = 14, loc='center')
sns.lineplot(x=df['Month'], y=df["Colombia coal price"], hue=df['Year'])
# Out:
# <Axes: title={'center': 'Seasonal plot of Colombia coal price'}, xlabel='Month', ylabel='Seasonal Plot for Colombia coal price'>

# %%
ax = sns.boxplot(data=df, x='Month', y='Colombia coal price')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90);

# %%
month_plot(df["Colombia coal price"],ylabel='Coal Price');

# %%
cls_decomposition = sm.tsa.seasonal_decompose(df["Colombia coal price"], model='additive')
fig = cls_decomposition.plot()
plt.show()

# %%
df["Colombia coal price"].plot(label="Original Colombia coal price")
df['Seasonally Adjusted'] = df['Colombia coal price'] - cls_decomposition.seasonal
df["Seasonally Adjusted"].plot(label="Seasonally Adjusted")
df["Trend/Seasonal Adjusted"] = df["Colombia coal price"] - cls_decomposition.seasonal- cls_decomposition.trend
df["Trend/Seasonal Adjusted"].plot(label="Trend/Seasonal Adjusted")
plt.legend();
plt.title("Adjusted Time Plot");

# %%
fig3,ax3 = plt.subplots(2,2,figsize=(20,13))
sns.boxplot(data=df, x='Month', y='Colombia coal price',ax=ax3[0][0]).set_title("Colombia coal price")
sns.boxplot(data=df, x='Month', y='Global coal price',ax=ax3[0][1]).set_title("Global coal price")
sns.boxplot(data=df, x='Month', y='Metal Index',ax=ax3[1][0]).set_title("Metal Index")
sns.boxplot(data=df, x='Month', y='Commodity Index',ax=ax3[1][1]).set_title("Commodity Index")
# Out:
# Text(0.5, 1.0, 'Commodity Index')

# %%
fig3,ax3 = plt.subplots(figsize=(20,13))
sns.boxplot(data=df, x='Month', y='Non-Fuel Index',ax=ax3).set_title("Non-Fuel Index")
# Out:
# Text(0.5, 1.0, 'Non-Fuel Index')

# %%
def calculate_whiskers(attribute,time,perspective):
    Q1=df.loc[df[perspective] == time, attribute].quantile(0.25)
    Q3=df.loc[df[perspective] == time, attribute].quantile(0.75)
    IQR=Q3-Q1
    Lower_Whisker = Q1 - 1.5*IQR
    Upper_Whisker = Q3 + 1.5*IQR
    return Upper_Whisker,Lower_Whisker

# %%
#For the target value "Colombia coal price"
df.sort_values(by=['Colombia coal price'],inplace=True)
months = [4,5,6,7,8,9]

for ind in df.index:
    for month in months:
        if (df['Month'][ind] == month): 
            Upper_Whisker,Lower_Whisker = calculate_whiskers("Colombia coal price",month,"Month")
            if(df['Colombia coal price'][ind] > Upper_Whisker):
                df.replace(df['Colombia coal price'][ind],(Upper_Whisker-1),inplace=True)
            elif(df['Colombia coal price'][ind] < Lower_Whisker):
                df.replace(df['Colombia coal price'][ind],(Lower_Whisker+1),inplace=True)
            else:
                continue      
ax = sns.boxplot(data=df, x='Month', y='Colombia coal price').set_title("Colombia coal price")

# %%
df.sort_values(by=['Global coal price'],inplace=True)
months = [6,7,8,9,11,12]

for ind in df.index:
    for month in months:
        if (df['Month'][ind] == month): 
            Upper_Whisker,Lower_Whisker = calculate_whiskers("Global coal price",month,"Month")
            if(df['Global coal price'][ind] > Upper_Whisker):
                df.replace(df['Global coal price'][ind],(Upper_Whisker-1),inplace=True)
            elif(df['Global coal price'][ind] < Lower_Whisker):
                df.replace(df['Global coal price'][ind],(Lower_Whisker+1),inplace=True)
            else:
                continue      
ax = sns.boxplot(data=df, x='Month', y='Global coal price').set_title("Global coal price")

# %%
fig3,ax3 = plt.subplots(2, figsize=(20,13))
sns.boxplot(data=df, x='Year', y='Colombia coal price',ax=ax3[0]).set_title("Colombia coal price")
sns.boxplot(data=df, x='Year', y='Global coal price',ax=ax3[1]).set_title("Global coal price")
# Out:
# Text(0.5, 1.0, 'Global coal price')

# %%
fig3,ax3 = plt.subplots(2, figsize=(20,13))
sns.boxplot(data=df, x='Year', y='Metal Index',ax=ax3[0]).set_title("Metal Index")
sns.boxplot(data=df, x='Year', y='Non-Fuel Index',ax=ax3[1]).set_title("Non-Fuel Index")
# Out:
# Text(0.5, 1.0, 'Non-Fuel Index')

# %%
fig3,ax3 = plt.subplots(figsize=(20,13))
sns.boxplot(data=df, x='Year', y='Commodity Index',ax=ax3).set_title("Commodity Index")
# Out:
# Text(0.5, 1.0, 'Commodity Index')

# %%
years = [2007,2008,2009,2010,2011]
for ind in df.index:
    for year in years:
        if (df['Year'][ind] == year): 
            Upper_Whisker,Lower_Whisker = calculate_whiskers("Colombia coal price",year,"Year")
            if(df['Colombia coal price'][ind] > Upper_Whisker):
                df.replace(df['Colombia coal price'][ind],(Upper_Whisker-1),inplace=True)
            elif(df['Colombia coal price'][ind] < Lower_Whisker):
                df.replace(df['Colombia coal price'][ind],(Lower_Whisker+1),inplace=True)
            else:
                continue

# %%
years = [2009,2010,2011,2015]
for ind in df.index:
    for year in years:
        if (df['Year'][ind] == year): 
            Upper_Whisker,Lower_Whisker = calculate_whiskers("Global coal price",year,"Year")
            if(df['Global coal price'][ind] > Upper_Whisker):
                df.replace(df['Global coal price'][ind],(Upper_Whisker-1),inplace=True)
            elif(df['Global coal price'][ind] < Lower_Whisker):
                df.replace(df['Global coal price'][ind],(Lower_Whisker+1),inplace=True)
            else:
                continue

# %%
fig3,ax3 = plt.subplots(2,figsize=(20,13))
sns.boxplot(data=df, x='Year', y='Colombia coal price',ax=ax3[0]).set_title("Colombia coal price after Outlier Removal")
sns.boxplot(data=df, x='Year', y='Global coal price',ax=ax3[1]).set_title("Global coal price after Outlier Removal")
# Out:
# Text(0.5, 1.0, 'Global coal price after Outlier Removal')

# %%
years = [2013,2016]
for ind in df.index:
    for year in years:
        if (df['Year'][ind] == year): 
            Upper_Whisker,Lower_Whisker = calculate_whiskers("Metal Index",year,"Year")
            if(df['Metal Index'][ind] > Upper_Whisker):
                df.replace(df['Metal Index'][ind],(Upper_Whisker-1),inplace=True)
            elif(df['Metal Index'][ind] < Lower_Whisker):
                df.replace(df['Metal Index'][ind],(Lower_Whisker+1),inplace=True)
            else:
                continue

# %%
years = [2010,2012,2014,2017]
for ind in df.index:
    for year in years:
        if (df['Year'][ind] == year): 
            Upper_Whisker,Lower_Whisker = calculate_whiskers("Commodity Index",year,"Year")
            if(df['Commodity Index'][ind] > Upper_Whisker):
                df.replace(df['Commodity Index'][ind],(Upper_Whisker-1),inplace=True)
            elif(df['Commodity Index'][ind] < Lower_Whisker):
                df.replace(df['Commodity Index'][ind],(Lower_Whisker+1),inplace=True)
            else:
                continue

# %%
fig3,ax3 = plt.subplots(2,figsize=(20,13))
sns.boxplot(data=df, x='Year', y='Metal Index',ax=ax3[0]).set_title("Metal Index after Outlier Removal")
sns.boxplot(data=df, x='Year', y='Commodity Index',ax=ax3[1]).set_title("Commodity Index after Outlier Removal")
# Out:
# Text(0.5, 1.0, 'Commodity Index after Outlier Removal')

# %%
years = [2011]
for ind in df.index:
    for year in years:
        if (df['Year'][ind] == year): 
            Upper_Whisker,Lower_Whisker = calculate_whiskers("Non-Fuel Index",year,"Year")
            if(df['Non-Fuel Index'][ind] > Upper_Whisker):
                df.replace(df['Non-Fuel Index'][ind],(Upper_Whisker-1),inplace=True)
            elif(df['Non-Fuel Index'][ind] < Lower_Whisker):
                df.replace(df['Non-Fuel Index'][ind],(Lower_Whisker+1),inplace=True)
            else:
                continue

# %%
fig3,ax3 = plt.subplots(figsize=(20,13))
sns.boxplot(data=df, x='Year', y='Non-Fuel Index',ax=ax3).set_title("Non-Fuel Index after Outlier Removal")
# Out:
# Text(0.5, 1.0, 'Non-Fuel Index after Outlier Removal')

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in d:\anaconda\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in d:\anaconda\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in d:\anaconda\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in d:\anaconda\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\lib\site-packages (from scikit-learn) (2.2.0)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in d:\anaconda\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in d:\anaconda\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.25.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)

# %%
import os
os.environ['SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL'] = 'True'

# %%
# !pip install talos
# Out:
# Requirement already satisfied: talos in d:\anaconda\lib\site-packages (1.3)
# Requirement already satisfied: tensorflow>=2.0.0 in d:\anaconda\lib\site-packages (from talos) (2.15.0)
# Requirement already satisfied: statsmodels>=0.11.0 in d:\anaconda\lib\site-packages (from talos) (0.14.0)
# Requirement already satisfied: wrangle in d:\anaconda\lib\site-packages (from talos) (0.7.2)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from talos) (1.24.3)
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (from talos) (2.0.3)
# Requirement already satisfied: astetik in d:\anaconda\lib\site-packages (from talos) (1.13)
# Requirement already satisfied: sklearn in d:\anaconda\lib\site-packages (from talos) (0.0.post12)
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from talos) (4.65.0)
# Requirement already satisfied: chances in d:\anaconda\lib\site-packages (from talos) (0.1.9)
# Requirement already satisfied: kerasplotlib in d:\anaconda\lib\site-packages (from talos) (1.0)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from talos) (2.31.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in d:\anaconda\lib\site-packages (from statsmodels>=0.11.0->talos) (1.11.1)
# Requirement already satisfied: patsy>=0.5.2 in d:\anaconda\lib\site-packages (from statsmodels>=0.11.0->talos) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in d:\anaconda\lib\site-packages (from statsmodels>=0.11.0->talos) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas->talos) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas->talos) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda\lib\site-packages (from pandas->talos) (2023.3)
# Requirement already satisfied: tensorflow-intel==2.15.0 in d:\anaconda\lib\site-packages (from tensorflow>=2.0.0->talos) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (4.23.4)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (2.15.0)
# Requirement already satisfied: seaborn in d:\anaconda\lib\site-packages (from astetik->talos) (0.12.2)
# Requirement already satisfied: IPython in d:\anaconda\lib\site-packages (from astetik->talos) (8.15.0)
# Requirement already satisfied: geonamescache in d:\anaconda\lib\site-packages (from astetik->talos) (2.0.0)
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (from kerasplotlib->talos) (3.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests->talos) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests->talos) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->talos) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->talos) (2023.11.17)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm->talos) (0.4.6)
# Requirement already satisfied: backcall in d:\anaconda\lib\site-packages (from IPython->astetik->talos) (0.2.0)
# Requirement already satisfied: decorator in d:\anaconda\lib\site-packages (from IPython->astetik->talos) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\lib\site-packages (from IPython->astetik->talos) (0.18.1)
# Requirement already satisfied: matplotlib-inline in d:\anaconda\lib\site-packages (from IPython->astetik->talos) (0.1.6)
# Requirement already satisfied: pickleshare in d:\anaconda\lib\site-packages (from IPython->astetik->talos) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in d:\anaconda\lib\site-packages (from IPython->astetik->talos) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in d:\anaconda\lib\site-packages (from IPython->astetik->talos) (2.15.1)
# Requirement already satisfied: stack-data in d:\anaconda\lib\site-packages (from IPython->astetik->talos) (0.2.0)
# Requirement already satisfied: traitlets>=5 in d:\anaconda\lib\site-packages (from IPython->astetik->talos) (5.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->kerasplotlib->talos) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib->kerasplotlib->talos) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib->kerasplotlib->talos) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->kerasplotlib->talos) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib->kerasplotlib->talos) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib->kerasplotlib->talos) (3.0.9)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (0.38.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda\lib\site-packages (from jedi>=0.16->IPython->astetik->talos) (0.8.3)
# Requirement already satisfied: wcwidth in d:\anaconda\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython->astetik->talos) (0.2.5)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (2.25.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (2.2.3)
# Requirement already satisfied: executing in d:\anaconda\lib\site-packages (from stack-data->IPython->astetik->talos) (0.8.3)
# Requirement already satisfied: asttokens in d:\anaconda\lib\site-packages (from stack-data->IPython->astetik->talos) (2.0.5)
# Requirement already satisfied: pure-eval in d:\anaconda\lib\site-packages (from stack-data->IPython->astetik->talos) (0.2.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.0.0->talos) (3.2.2)

# %%
# importing libraries
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import activations
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import matplotlib as mpl

import talos
from plot_keras_history import plot_history


# mpl.rcParams['figure.figsize'] = (12,10)
mpl.rcParams['axes.grid'] = True

# %%
# rearranging dataframe columns to have target column at the first column for easy preprocessing
df = df[['Colombia coal price', 'Global coal price', 'Metal Index','Non-Fuel Index', 'Commodity Index']]

# %%
# checking first 5 rows of dataframe
df.head()
# Out:
#             Colombia coal price  Global coal price  Metal Index  \
# Date
# 2016-01-01                43.01            48.8000        55.21
# 2016-02-01                41.38            50.5000        57.68
# 2015-12-01                44.70            58.3125        56.31
# 2016-04-01                43.12            50.7500        62.00
# 2016-03-01                43.84            51.1000        61.19
#
#             Non-Fuel Index  Commodity Index
# Date
# 2016-01-01           74.03            40.01
# 2016-02-01           74.60            40.78
# 2015-12-01           75.47            47.37
# 2016-04-01           78.83            51.01
# 2016-03-01           76.99            47.20

# %%
#converting series to supervised learning dataset
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
# storing row values as array
values = df.values
df.dtypes
# Out:
# Colombia coal price    float64
# Global coal price      float64
# Metal Index            float64
# Non-Fuel Index         float64
# Commodity Index        float64
# dtype: object

# %%
# Scaling full data using the MinMaxScaler, since all the column values are float
# variables that are measured at different scales do not contribute equally to the model fitting 
# and might end up creating a bias. Thus, to deal with this potential problem, feature-wise normalization 
# such as MinMax Scaling is usually used prior to model fitting
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(values)

# changing data to supervised data as described above
reframed_data = series_to_supervised(data_scaled, 1,1)

# %%
# checking head of supervised data
reframed_data.head()
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)   var1(t)   var2(t)  \
# 1   0.021471   0.000000   0.060558   0.003501   0.000000  0.000000  0.019533
# 2   0.000000   0.019533   0.093217   0.014004   0.005771  0.043733  0.109298
# 3   0.043733   0.109298   0.075102   0.030035   0.055164  0.022920  0.022405
# 4   0.022920   0.022405   0.150337   0.091948   0.082446  0.032405  0.026427
# 5   0.032405   0.026427   0.139627   0.058043   0.053890  0.129223  0.028610
#
#     var3(t)   var4(t)   var5(t)
# 1  0.093217  0.014004  0.005771
# 2  0.075102  0.030035  0.055164
# 3  0.150337  0.091948  0.082446
# 4  0.139627  0.058043  0.053890
# 5  0.610869  0.125299  0.248838

# %%
reframed_data.shape
# Out:
# (131, 10)

# %%
#only keep data till time t; t+1, t2, ...all till the end can be dropped, since we only need to predict the target variable at time t
reframed_data.drop(['var2(t)','var3(t)', 'var4(t)', 'var5(t)'], axis=1, inplace=True)

# %%
# storing dataframe as array 
values = reframed_data.values

# %%
# 根据您的要求分割数据集
train = values[:91, :]
test = values[-40:, :]
# 分离特征和目标变量
# 假设第一列是目标变量

train_x, train_y = train[:, :-1], train[:, -1]
test_x, test_y = test[:, :-1], test[:, -1]



# 预测
pred_test_y = model.predict(test_x)
pred_train_y = model.predict(train_x)

mae_train = mean_absolute_error(train_y, pred_train_y)
mse_train = mean_squared_error(train_y, pred_train_y)
r2_train = r2_score(train_y, pred_train_y)

mae_test = mean_absolute_error(test_y, pred_test_y)
mse_test = mean_squared_error(test_y, pred_test_y)
r2_test = r2_score(test_y, pred_test_y)
rmse = np.sqrt(mse_test)

evaluation_metrics = {
    "Training Set": {
        "Mean Absolute Error (MAE)": mae_train,
        "Mean Squared Error (MSE)": mse_train,
        "R-squared": r2_train
    },
    "Test Set": {
        "Mean Absolute Error (MAE)": mae_test,
        "Mean Squared Error (MSE)": mse_test,
        "R-squared": r2_test
    }
}

evaluation_metrics



# 创建SVR模型
model = SVR(kernel='linear', C=5, gamma=0.1, epsilon=0.1)

# 训练模型
model.fit(train_x, train_y)

# 进行预测
y_pred = model.predict(test_x)

print(f"Mean Squared Error: {mse_test}")
print(f"R-squared: {r2_test}")
print(rmse)
print(mae_test)



# 绘制训练集的实际值和预测值
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
plt.plot(train[:, -1], label='Actual Training Values', color='blue')  # 实际值
plt.plot(pred_train_y, label='Predicted Training Values', color='orange')  # 预测值
plt.title('Training Set: Actual vs Predicted')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()

# 绘制测试集的实际值和预测值
plt.subplot(1, 2, 2)
plt.plot(test[:, -1], label='Actual Test Values', color='blue')  # 实际值
plt.plot(pred_test_y, label='Predicted Test Values', color='orange')  # 预测值
plt.title('Test Set: Actual vs Predicted')
plt.xlabel('Index')
plt.ylabel('Values')
plt.legend()
# Out:
# Mean Squared Error: 0.01493878265163645
# R-squared: 0.6563588054029059
# 0.12222431284992545
# 0.09196354094311679
